# %% [markdown]
# # Course Title: Programming Language II
# Course Code: CSE 111
#
# Lab Assignment No.02

# %%
#STUDENT NAME: Umama Tasnuva Aziz
#STUDENT ID: 21301570
#CSE111 SECTION: 10

# %% [markdown]
# 1. Write a function which will return the fraction part after dividing a number by another. The range should be within 0 and 1. Exception: Since dividing anything by 0 results in error so if the denominator is 0, the function will return 0 instead of attempting the division.

# %%
 #Task 1
def fraction(num1, num2):
    if(num == 0 or x == 0):
        print("0")
    else: 
        return x/y - x//y
x = int((input("Enter a number: ")))
y = int((input("Enter another number: ")))
a = fraction(x, y)
print(a)
# Out:
# Enter a number: 5
# Enter another number: 2
# 0.5

# %% [markdown]
# 2. You are one of the gym instructors at AmiKenoMota. You decide to provide a
# customized diet and exercise plans based on the BMI of an individual. You measure the weight in kilograms and height in meters and calculate the BMI before a plan can be decided. Write a BMI function that takes in two values, weight in kg and height in cm and print the score along with the condition. (Make sure to convert cm into m before calculation)
#
# BMI(height, weight)    𝐵𝑀𝐼 = 𝑘𝑔/𝑚2
#
# Based on the BMI score return the following output.
#
# ● < 18.5- Underweight
#
# ● 18.5 - 24.9 - Normal
#
# ● 25 -30 - Overweight
#
# ● > 30 – Obese

# %%
#Task 2
def bmi(height, weight):
    return weight/height
h = float(input("Enter the height in cm: "))
weight = float(input("Enter the weight in kg: "))
height = (h/100)**2
x = bmi(height, weight)
if (x<18.5):
    print("Score is", x,"you are Underweight")
elif (x >= 18.5 and x <= 24.9):
    print("Score is",x,"you are Normal")
elif (x >= 25 and x <= 30):
    print("Score is", x, "you are Overweight")
else:
    print("Score is", x, "you are Obese")
# Out:
# Enter the height in cm: 175
# Enter the weight in kg: 96
# Score is 31.346938775510203 you are Obese

# %% [markdown]
# 3. Write a function which will take 3 arguments minimum, maximum and divisor.
# You have to find all the numbers that are divisible by the divisor where minimum
# value is inclusive and maximum value is exclusive. Add all the numbers and return the value.

# %%
#Task 3
def function(minimum, maximum, divisor):
    x = 0
    for i in range(minimum, maximum, divisor):
        x = x + i
    return x
minimum = int(input("Enter the minimum value: "))
maximum = int(input("Enter the maximum value: "))
divisor = int(input("Enter the value for divisor: ")) 
x = function(minimum, maximum, divisor)
print(x)
# Out:
# Enter the minimum value: 3
# Enter the maximum value: 16
# Enter the value for divisor: 3
# 45

# %% [markdown]
# 4. You want to order Burger from Chillox through the FoodPanda App. You have to
# calculate the total price. Write a function which will take the name of the burger and place(Mohakhali/Outside of Mohakhali) as input. Use default argument technique for taking place input.

# %%
#Task 4
def chillox(name, place = ""):
  price = int()
  tax = int()
  charge = int()
  tax = int()
  if(name == "BBQ Chicken Cheese Burger"):
    price = 250
  if(name == "Beef Burger"):
    price = 170
  elif(name == "Naga Drums"):
    price = 200
  if(place == "Mohakhali" or place == ""):
    charge = 40
  elif(place != "Mohakhali"): 
    charge = 60
  tax = price*(8/100)
  total = price + charge + tax 
  return total
name = input("Enter the meal name: ")
place = input("Enter the place: ")
x = chillox(name, place)
print(x)
# Out:
# Enter the meal name: Beef Burger
# Enter the place: Dhanmondi
# 243.6

# %% [markdown]
# 5. A company named Sheba.xyz has recently moved from their old domain to a new
# domain. However, a lot of the company email addresses are still using the old one. Write a function in python that replaces this old domain with the new one in any outdated email addresses. Keep same if the email address contains the new domain.
#
# (Do not use builtin replace function)
#
# Firstly, define a “replace_domain” function which accepts three parameters
#
#  *The email address to be checked
#
#  *The new domain
#
#  *The old domain (Use Default argument technique to handle this)

# %%
#Task 5
def replace_domain(email, new, old = ""):
  line = email.split("@")
  y = line[0] + "@" + new
  if old == "":
    return ("Unchanged", y)
  else:
    return ("Changed", y)
email = input("Enter the email to be changed: ")
new = input("Enter the new domain: ")
old = input("Enter the old domain: ")
print(replace_domain(email,new, old))
# Out:
# Enter the email to be changed: alice@kaaj.com
# Enter the new domain: sheba.xyz
# Enter the old domain: kaaj.com
# ('Changed', 'alice@sheba.xyz')

# %% [markdown]
# 6. Write a function which takes only your full name as input and finds the total
# number of vowels in that input. Output every vowel and at the end output the total number of vowelsfound. If your name does not contain any vowel then your function should print “No vowels in the name!”.

# %%
#Task 6
def functn(w):
    vl = ['a','e','i','o','u']
    st = ''
    count = 0
    for i in (range(len(inp))):
        if w[i] in vl:
            count += 1
            st += w[i]
    if count == 0:
        print('No vowels in the name')
    else:
        print('Vowels: ', end = '')
        for i in range(len(st) - 1):
            n = st[i]
            print(n + ', ', end = '')
        print(st[-1] + '.', end ='')
        print(' Total number of vowels:', count)
inp = input()
functn(inp)
# Out:
# Steve Jobs
# Vowels: e, e, o. Total number of vowels: 3

# %% [markdown]
# 7. Write a program which checks whether a given string is a palindrome or not. Note: A palindrome is a word, phrase, or sequence that reads the same backward as forward. For palindrome, any spaces in middle are not considered and should be trimmed.

# %%
#Task 7
word = input("Enter a word or a sentence or a phrase: ")
word = word.replace(" ", "")
p = reversed(word)
if list(word) == list(p):
  print("Palindrome")
else:
  print('Not a palindrome')
# Out:
# Enter a word or a sentence or a phrase: madam
# Palindrome

# %% [markdown]
# 8. Write a function which takes a number of days as input and prints total number of years, number of months and remaining number of days as output.

# %%
#Task 8
def format(date):
  x = date//365
  y = x*365
  year = x
  z = date - y
  a = z//30
  c = a*30
  month = a
  b = z - c
  day = b
  print(year, "years,", month, "months", "and", day, "days")
date = int(input("Enter the number of days: "))
format(date)
# Out:
# Enter the number of days: 4320
# 11 years, 10 months and 5 days

# %% [markdown]
# 9. You are a class teacher at a kindergarten school. As a task, you asked your
# students to write a paragraph. Unfortunately, you notice that most of the students did not use capital letters correctly. Your task is to write a function which takes a string as its only parameter and returns a new copy of the string that has been correctly capitalized. Your function should:
#
# ● Capitalize the first letter in the string
#
# ● Capitalize the first letter after a full-stop, exclamation mark or question mark
#
# ● Capitalize the word “i” if it is in lowercase.
#
# Summary: You have to write a function that reads a string from the user and
# capitalizes. The string is then returned and displayed.

# %%
#Task 9
def my_func(string):
    my_list = list(string)
    my_list[0] = my_list[0].upper()
    for i in range(1, len(string) - 1):
        if string[i] == '?' or string[i] == '.' or string[i] == '!':
            my_list[i + 2] = string[i + 2].upper()
        elif string[i] == ' ' and string[i + 1] == 'i' and string[i + 2] == ' ':
            my_list[i + 1] = my_list[i + 1].upper()
    for i in range(0, len(my_list)):
        print(my_list[i], end = '')
    return('')
string = input('enter your lines: ')
print(my_func(string))
# Out:
# enter your lines: my favourite animal is a dog. a dog has sharp teeth so that it can eat flesh very easily. do you know my pet dog’s name? i love my pet very much.
# My favourite animal is a dog. A dog has sharp teeth so that it can eat flesh very easily. Do you know my pet dog’s name? I love my pet very much.
